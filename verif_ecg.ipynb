# %%
import numpy as np
import matplotlib.pyplot as plt
from params import *
from preproc import convert_vhdr_job

# %%
for subject in subject_keys:
    fig, axs = plt.subplots(ncols = len(session_keys), figsize = (12,4))
    for c, session in enumerate(session_keys):
        ax = axs[c]
        run_key = f'{subject}_{session}'
        ecg = convert_vhdr_job.get(run_key)['raw'].loc['ECG',0:10].values
        ax.plot(ecg)
        ax.set_title(run_key)
    plt.show()
# Out:
# convert_vhdr is processing ('P01_baseline',)
# convert_vhdr is processing ('P01_music',)
# convert_vhdr is processing ('P01_odor',)
# convert_vhdr is processing ('P02_baseline',)
# convert_vhdr is processing ('P02_music',)
# convert_vhdr is processing ('P02_odor',)
# convert_vhdr is processing ('P03_baseline',)
# convert_vhdr is processing ('P03_music',)
# convert_vhdr is processing ('P03_odor',)
# convert_vhdr is processing ('P04_baseline',)
# convert_vhdr is processing ('P04_music',)
# convert_vhdr is processing ('P04_odor',)
# convert_vhdr is processing ('P05_baseline',)
# convert_vhdr is processing ('P05_music',)
# convert_vhdr is processing ('P05_odor',)
# convert_vhdr is processing ('P06_baseline',)
# convert_vhdr is processing ('P06_music',)
# convert_vhdr is processing ('P06_odor',)
# convert_vhdr is processing ('P07_baseline',)
# convert_vhdr is processing ('P07_music',)
# convert_vhdr is processing ('P07_odor',)
# convert_vhdr is processing ('P08_baseline',)
# ...
