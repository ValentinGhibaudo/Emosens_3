# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import ghibtools as gh
import pandas as pd
import seaborn as sns
import pingouin as pg
from params import *
from bibliotheque import *
from configuration import base_folder
import os

# %%
save_folder = base_folder / 'Figures' / 'stimulus_scoring'

# %%
concat = []
for participant in subject_keys:
    ses01_folder = base_folder / 'Data' / f'{participant}' / 'questionnaires' / 'ses01'
    df_participant = pd.read_excel(ses01_folder / f'cotations_odeurs_absolues_{participant}.xlsx')
    concat.append(df_participant)
cotations_absolues_odeurs = pd.concat(concat)

# %%
concat = []
for participant in subject_keys:
    ses01_folder = base_folder / 'Data' / f'{participant}' / 'questionnaires' / 'ses01'
    df_participant = pd.read_excel(ses01_folder / f'cotations_musiques_absolues_{participant}.xlsx')
    concat.append(df_participant)
cotations_absolues_musiques = pd.concat(concat)

# %%
cotations_absolues_odeurs
# Out:
#    participant  odeur_num odeur_label             odeur_name  \
# 0          P01          1          FO      Feuille d'Olivier
# 1          P01          2          FP      Floral Printanier
# 2          P01          3           R                   Rose
# 3          P01          4          PL          Pêche Lavande
# 4          P01          5         FoE  Fleur d'oranger épicé
# ..         ...        ...         ...                    ...
# 5          P31          6          FC         Fleur de coton
# 6          P31          7           V                Vanille
# 7          P31          8          BO             Blue Ocean
# 8          P31          9          BE             Bois épicé
# 9          P31         10          Ox                Oxygène
#
#     hédonicité_absolue_brute  longueur_totale  hédonicité_absolue
# 0                         74              100                0.74
# 1                         85              100                0.85
# 2                         26              100                0.26
# 3                         40              100                0.40
# 4                         77              100                0.77
# ..                       ...              ...                 ...
# 5                         85              100                0.85
# 6                         92              100                0.92
# 7                         77              100                0.77
# 8                         57              100                0.57
# 9                         84              100                0.84
#
# [300 rows x 7 columns]

# %%
cotations_absolues_odeurs.describe()
# Out:
#        odeur_num  hédonicité_absolue_brute  longueur_totale  \
# count  300.00000                300.000000            300.0
# mean     5.50000                 64.590000            100.0
# std      2.87708                 24.568828              0.0
# min      1.00000                  0.000000            100.0
# 25%      3.00000                 50.000000            100.0
# 50%      5.50000                 66.000000            100.0
# 75%      8.00000                 85.250000            100.0
# max     10.00000                100.000000            100.0
#
#        hédonicité_absolue
# count          300.000000
# mean             0.645900
# std              0.245688
# min              0.000000
# 25%              0.500000
# 50%              0.660000
# 75%              0.852500
# max              1.000000

# %%
cotations_absolues_musiques.describe()
# Out:
#        musique_num  appréciation_absolue  longueur_totale  \
# count    300.00000            110.000000       300.000000
# mean       5.50000             65.345455       101.666667
# std        2.87708             27.726527         8.990271
# min        1.00000              0.000000       100.000000
# 25%        3.00000             50.000000       100.000000
# 50%        5.50000             73.500000       100.000000
# 75%        8.00000             86.000000       100.000000
# max       10.00000            100.000000       150.000000
#
#        appréciation_absolue_normalisée  hédonicité_absolue_brute  \
# count                       110.000000                190.000000
# mean                          0.659333                 62.236842
# std                           0.251742                 26.091652
# min                           0.000000                  0.000000
# 25%                           0.500000                 45.000000
# 50%                           0.710000                 65.500000
# 75%                           0.857500                 83.000000
# max                           1.000000                100.000000
#
#        hédonicité_absolue
# count          190.000000
# mean             0.636526
# std              0.257605
# min              0.000000
# 25%              0.490000
# 50%              0.690000
# 75%              0.837500
# max              1.000000

# %%
cotations_absolues_musiques
# Out:
#    participant  musique_num musique_name  appréciation_absolue  \
# 0          P01            1      Classic                  89.0
# 1          P01            2      Electro                  88.0
# 2          P01            3    Hard_Rock                   5.0
# 3          P01            4         Jazz                   3.0
# 4          P01            5        Metal                  50.0
# ..         ...          ...          ...                   ...
# 5          P31            6          Pop                   NaN
# 6          P31            7         Raga                   NaN
# 7          P31            8   Rap_Freeze                   NaN
# 8          P31            9      Rap_Luv                   NaN
# 9          P31           10      Variety                   NaN
#
#     longueur_totale  appréciation_absolue_normalisée  \
# 0               150                         0.593333
# 1               150                         0.586667
# 2               150                         0.033333
# 3               150                         0.020000
# 4               150                         0.333333
# ..              ...                              ...
# 5               100                              NaN
# 6               100                              NaN
# 7               100                              NaN
# 8               100                              NaN
# 9               100                              NaN
#
#     hédonicité_absolue_brute  hédonicité_absolue
# 0                        NaN                 NaN
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
# ..                       ...                 ...
# 5                       80.0                0.80
# 6                       29.0                0.92
# 7                       89.0                0.89
# 8                       66.0                0.66
# 9                       92.0                0.92
#
# [300 rows x 8 columns]

# %%
fig, axs = plt.subplots(nrows =2, figsize = (15,12), constrained_layout = True)

N = cotations_absolues_musiques['participant'].unique().size

fig.suptitle(f'Hédonicité absolue , N = {N}', fontsize = 20)

ax = axs[0]
sns.boxplot(data=cotations_absolues_odeurs, x='odeur_name', y = 'hédonicité_absolue', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45)
ax.axhline(0.5, color ='r', lw = 5)
ax.set_title('Odeurs', fontsize = 15)
ax.set_ylabel('Appréciation / 1', fontsize = 15)
ax.set_xlabel('')
ax.set_ylim(-0.1,1.1)

ax = axs[1]
sns.boxplot(data=cotations_absolues_musiques, x='musique_name', y = 'appréciation_absolue_normalisée', ax=ax)
ax.axhline(0.5, color ='r', lw = 5)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45)
ax.set_title('Musiques', fontsize = 15)
ax.set_ylabel('Appréciation / 1', fontsize = 15)
ax.set_xlabel('')
ax.set_ylim(-0.1,1.1)

file = save_folder / 'hédonicité_absolue.png'

fig.savefig(file, bbox_inches = 'tight', dpi = 300)

# %%
concat = []
for participant in subject_keys:
    ses01_folder = base_folder / 'Data' / f'{participant}' / 'questionnaires' / 'ses01'
    df_participant = pd.read_excel(ses01_folder /  f'cotations_odeurs_relatives_{participant}_bis.xlsx')
    concat.append(df_participant)
cotations_relatives_odeurs = pd.concat(concat)

# %%
concat = []
for participant in subject_keys:
    ses01_folder = base_folder / 'Data' / f'{participant}' / 'questionnaires' / 'ses01'
    df_participant = pd.read_excel(ses01_folder /  f'cotations_musiques_relatives_{participant}_bis.xlsx', index_col = 0)
    concat.append(df_participant)
cotations_relatives_musiques = pd.concat(concat)

# %%
cotations_relatives_musiques
# Out:
#    participant  musique_num musique_name  hédonicité_absolue_brute  \
# 0          P01            1      Classic                        89
# 1          P01            2      Electro                        88
# 2          P01           10      Variety                        82
# 0          P02            1      Classic                        97
# 1          P02            6          Pop                        97
# ..         ...          ...          ...                       ...
# 1          P30            2      Electro                       100
# 2          P30            5        Metal                        93
# 0          P31            5        Metal                        97
# 1          P31            8   Rap Freeze                        89
# 2          P31           10      Variety                        92
#
#     hédonicité_absolue  longueur_totale  intensité_relative_brute  \
# 0                 0.89              100                        31
# 1                 0.88              100                        63
# 2                 0.82              100                        74
# 0                 0.97              100                        17
# 1                 0.97              100                        90
# ..                 ...              ...                       ...
# 1                 1.00              100                        98
# 2                 0.93              100                        95
# 0                 0.97              100                        81
# 1                 0.89              100                        24
# 2                 0.92              100                        53
#
#     intensité_relative  hédonicité_relative_brute  hédonicité_relative  \
# 0                 0.31                         87                 0.87
# 1                 0.63                         72                 0.72
# 2                 0.74                         80                 0.80
# 0                 0.17                         89                 0.89
# 1                 0.90                          6                 0.06
# ..                 ...                        ...                  ...
# 1                 0.98                         97                 0.97
# 2                 0.95                         93                 0.93
# 0                 0.81                         97                 0.97
# 1                 0.24                         89                 0.89
# 2                 0.53                         76                 0.76
#
#     eveil_relatif_brute  eveil_relatif  familarité_relative_brute  \
# 0                    59           0.59                         90
# 1                    31           0.31                         62
# 2                    79           0.79                         72
# 0                     9           0.09                         99
# 1                    93           0.93                         13
# ..                  ...            ...                        ...
# 1                    99           0.99                        100
# 2                    95           0.95                         55
# 0                    95           0.95                         88
# 1                    24           0.24                         68
# 2                    78           0.78                         79
#
#     familiarité_relative  valence_émotionnelle_relative_brute  \
# 0                   0.90                                   78
# 1                   0.62                                   87
# 2                   0.72                                   64
# 0                   0.99                                   93
# 1                   0.13                                    4
# ..                   ...                                  ...
# 1                   1.00                                   83
# 2                   0.55                                   80
# 0                   0.88                                   79
# 1                   0.68                                   27
# 2                   0.79                                   96
#
#     valence_émotionnelle_relative
# 0                            0.78
# 1                            0.87
# 2                            0.64
# 0                            0.93
# 1                            0.04
# ..                            ...
# 1                            0.83
# 2                            0.80
# 0                            0.79
# 1                            0.27
# 2                            0.96
#
# [90 rows x 16 columns]

# %%
metrics = ['hédonicité_absolue','hédonicité_relative','intensité_relative','familiarité_relative','eveil_relatif','valence_émotionnelle_relative']
corr_method = 'spearman'

fig, axs = plt.subplots(ncols =2 , figsize = (15,7), constrained_layout = True)
fig.suptitle(f'Matrices de correlations ({corr_method}) entre cotations relatives des stimulus', fontsize = 20, y = 1.05)



ax = axs[0]
N = cotations_relatives_odeurs.shape[0]
sns.heatmap(cotations_relatives_odeurs.loc[:,metrics].corr(corr_method,numeric_only = True), cmap = 'seismic', vmin = -1, vmax =1, annot = True, ax=ax)
ax.set_title(f'Cotations des odeurs (N = {N})')

ax = axs[1]
N = cotations_relatives_musiques.shape[0]
sns.heatmap(cotations_relatives_musiques.loc[:,metrics].corr(corr_method,numeric_only = True), cmap = 'seismic', vmin = -1, vmax =1, annot = True, ax=ax)
ax.set_title(f'Cotations des musiques (N = {N})')

file = save_folder / f'matrice_correlation_{corr_method}.png'

fig.savefig(file, bbox_inches = 'tight')

# %%
metrics = ['hédonicité_relative','intensité_relative','familiarité_relative','eveil_relatif','valence_émotionnelle_relative']

fig, axs = plt.subplots(nrows = len(metrics), ncols = 2, figsize = (20,20), constrained_layout = True)

N = cotations_relatives_odeurs['participant'].unique().size

fig.suptitle(f'Cotations relatives par échantillon, N = {N}', fontsize = 20)

for r, metric in enumerate(metrics):
    for c, cotations_relatives in enumerate([cotations_relatives_odeurs, cotations_relatives_musiques]):
        
        ax = axs[r,c]
        
        if c == 0:
            stim = 'odeurs'
            x_label = 'odeur_name'
        else:
            stim = 'musiques'
            x_label = 'musique_name'
        
        
            
        sns.boxplot(data=cotations_relatives, x=x_label, y = metric, ax=ax)
        ax.set_title(f'{metric} des {stim}')
        ax.axhline(0.5, color ='r', lw = 2)
        ax.set_xticklabels(ax.get_xticklabels(), rotation = 45)
        ax.set_ylim(-0.1,1.1)
        ax.set_ylabel('/ 1')
        ax.set_xlabel('')
        
file = save_folder / f'cotations_relatives_ses01.png'


fig.savefig(file, bbox_inches = 'tight')

# %%
cotations_relatives_musiques
# Out:
#    participant  musique_num musique_name  hédonicité_absolue_brute  \
# 0          P01            1      Classic                        89
# 1          P01            2      Electro                        88
# 2          P01           10      Variety                        82
# 0          P02            1      Classic                        97
# 1          P02            6          Pop                        97
# ..         ...          ...          ...                       ...
# 1          P30            2      Electro                       100
# 2          P30            5        Metal                        93
# 0          P31            5        Metal                        97
# 1          P31            8   Rap Freeze                        89
# 2          P31           10      Variety                        92
#
#     hédonicité_absolue  longueur_totale  intensité_relative_brute  \
# 0                 0.89              100                        31
# 1                 0.88              100                        63
# 2                 0.82              100                        74
# 0                 0.97              100                        17
# 1                 0.97              100                        90
# ..                 ...              ...                       ...
# 1                 1.00              100                        98
# 2                 0.93              100                        95
# 0                 0.97              100                        81
# 1                 0.89              100                        24
# 2                 0.92              100                        53
#
#     intensité_relative  hédonicité_relative_brute  hédonicité_relative  \
# 0                 0.31                         87                 0.87
# 1                 0.63                         72                 0.72
# 2                 0.74                         80                 0.80
# 0                 0.17                         89                 0.89
# 1                 0.90                          6                 0.06
# ..                 ...                        ...                  ...
# 1                 0.98                         97                 0.97
# 2                 0.95                         93                 0.93
# 0                 0.81                         97                 0.97
# 1                 0.24                         89                 0.89
# 2                 0.53                         76                 0.76
#
#     eveil_relatif_brute  eveil_relatif  familarité_relative_brute  \
# 0                    59           0.59                         90
# 1                    31           0.31                         62
# 2                    79           0.79                         72
# 0                     9           0.09                         99
# 1                    93           0.93                         13
# ..                  ...            ...                        ...
# 1                    99           0.99                        100
# 2                    95           0.95                         55
# 0                    95           0.95                         88
# 1                    24           0.24                         68
# 2                    78           0.78                         79
#
#     familiarité_relative  valence_émotionnelle_relative_brute  \
# 0                   0.90                                   78
# 1                   0.62                                   87
# 2                   0.72                                   64
# 0                   0.99                                   93
# 1                   0.13                                    4
# ..                   ...                                  ...
# 1                   1.00                                   83
# 2                   0.55                                   80
# 0                   0.88                                   79
# 1                   0.68                                   27
# 2                   0.79                                   96
#
#     valence_émotionnelle_relative
# 0                            0.78
# 1                            0.87
# 2                            0.64
# 0                            0.93
# 1                            0.04
# ..                            ...
# 1                            0.83
# 2                            0.80
# 0                            0.79
# 1                            0.27
# 2                            0.96
#
# [90 rows x 16 columns]

# %%
concat_musique = cotations_relatives_musiques.drop(columns = ['musique_num','musique_name'])
concat_musique['Stimulus'] = 'Musique'
concat_odeur = cotations_relatives_odeurs.drop(columns = ['odeur_num','odeur_label','odeur_name','Unnamed: 0'])
concat_odeur['Stimulus'] = 'Odeur'
both_relatives = pd.concat([concat_musique, concat_odeur])

# %%
fig, axs = plt.subplots(ncols = 2, figsize = (15,5))
ax = axs[0]
gh.auto_stats(df = both_relatives,
              predictor = 'Stimulus',
              outcome = 'hédonicité_absolue',
              ax=ax,
              subject = 'participant',
              outcome_clean_label = 'Hedonicity (absolute step)',
              design = 'between',
              outcome_unit = '/ 1'
             )


ax = axs[1]
gh.auto_stats(df = both_relatives,
              predictor = 'Stimulus',
              outcome = 'hédonicité_relative',
              ax=ax,
              subject = 'participant',
              design = 'between',
              outcome_clean_label = 'Hedonicity (relative step)',
              outcome_unit = '/ 1'
             )

fig.savefig(base_folder / 'Figures' / 'stimulus_scoring' / 'absolute_and_relative_hedo_comparison.png', dpi = 300, bbox_inches = 'tight')

# %%
both_relatives
# Out:
#    participant  hédonicité_absolue_brute  hédonicité_absolue  longueur_totale  \
# 0          P01                        89                0.89              100
# 1          P01                        88                0.88              100
# 2          P01                        82                0.82              100
# 0          P02                        97                0.97              100
# 1          P02                        97                0.97              100
# ..         ...                       ...                 ...              ...
# 1          P30                        92                0.92              100
# 2          P30                        91                0.91              100
# 0          P31                        98                0.98              100
# 1          P31                        94                0.94              100
# 2          P31                        92                0.92              100
#
#     intensité_relative_brute  intensité_relative  hédonicité_relative_brute  \
# 0                         31                0.31                         87
# 1                         63                0.63                         72
# 2                         74                0.74                         80
# 0                         17                0.17                         89
# 1                         90                0.90                          6
# ..                       ...                 ...                        ...
# 1                          9                0.09                         61
# 2                         88                0.88                         68
# 0                         60                0.60                         80
# 1                         66                0.66                         89
# 2                         32                0.32                         57
#
#     hédonicité_relative  eveil_relatif_brute  eveil_relatif  \
# 0                  0.87                   59           0.59
# 1                  0.72                   31           0.31
# 2                  0.80                   79           0.79
# 0                  0.89                    9           0.09
# 1                  0.06                   93           0.93
# ..                  ...                  ...            ...
# 1                  0.61                    4           0.04
# 2                  0.68                   90           0.90
# 0                  0.80                   71           0.71
# 1                  0.89                   82           0.82
# 2                  0.57                   54           0.54
#
#     familarité_relative_brute  familiarité_relative  \
# 0                          90                  0.90
# 1                          62                  0.62
# 2                          72                  0.72
# 0                          99                  0.99
# 1                          13                  0.13
# ..                        ...                   ...
# 1                          61                  0.61
# 2                          80                  0.80
# 0                          73                  0.73
# 1                          99                  0.99
# 2                          79                  0.79
#
#     valence_émotionnelle_relative_brute  valence_émotionnelle_relative  \
# 0                                    78                           0.78
# 1                                    87                           0.87
# 2                                    64                           0.64
# 0                                    93                           0.93
# 1                                     4                           0.04
# ..                                  ...                            ...
# 1                                    53                           0.53
# 2                                    65                           0.65
# 0                                    66                           0.66
# 1                                    82                           0.82
# 2                                    68                           0.68
#
#    Stimulus
# 0   Musique
# 1   Musique
# 2   Musique
# 0   Musique
# 1   Musique
# ..      ...
# 1     Odeur
# 2     Odeur
# 0     Odeur
# 1     Odeur
# 2     Odeur
#
# [180 rows x 15 columns]

# %% [markdown]
# ### STIMS CHOISIS

# %%
musiques_choisies = cotations_relatives_musiques.groupby('participant').max(True).iloc[:,1:].reset_index()
musiques_choisies['Stimulus'] = 'Music'
odeurs_choisies = cotations_relatives_odeurs.groupby('participant').max(True).iloc[:,2:].reset_index()
odeurs_choisies['Stimulus'] = 'Odor'
odeurs_choisies
# Out:
#    participant  hédonicité_absolue_brute  hédonicité_absolue  longueur_totale  \
# 0          P01                        85                0.85              100
# 1          P02                        96                0.96              100
# 2          P03                       100                1.00              100
# 3          P04                        86                0.86              100
# 4          P05                        95                0.95              100
# 5          P06                        89                0.89              100
# 6          P07                        97                0.97              100
# 7          P08                        94                0.94              100
# 8          P09                        99                0.99              100
# 9          P10                        96                0.96              100
# 10         P11                        92                0.92              100
# 11         P12                        90                0.90              100
# 12         P13                        98                0.98              100
# 13         P14                        94                0.94              100
# 14         P15                        79                0.79              100
# 15         P16                        99                0.99              100
# 16         P17                        88                0.88              100
# 17         P18                        97                0.97              100
# 18         P19                       100                1.00              100
# 19         P20                       100                1.00              100
# 20         P21                        93                0.93              100
# 21         P23                        97                0.97              100
# 22         P24                        81                0.81              100
# 23         P25                        90                0.90              100
# 24         P26                       100                1.00              100
# 25         P27                        88                0.88              100
# 26         P28                        85                0.85              100
# 27         P29                        86                0.86              100
# 28         P30                        95                0.95              100
# 29         P31                        98                0.98              100
#
#     intensité_relative_brute  intensité_relative  hédonicité_relative_brute  \
# 0                         87                0.87                         85
# 1                         96                0.96                         99
# 2                         86                0.86                         80
# 3                         65                0.65                         81
# 4                         73                0.73                         86
# 5                         95                0.95                         87
# 6                         96                0.96                         93
# 7                         84                0.84                         87
# 8                         59                0.59                         94
# 9                         98                0.98                         97
# 10                        71                0.71                         86
# 11                        94                0.94                         95
# 12                        81                0.81                         91
# 13                        98                0.98                         94
# 14                        89                0.89                         74
# 15                        65                0.65                         81
# 16                        88                0.88                         94
# 17                        74                0.74                         93
# 18                        74                0.74                         99
# 19                        85                0.85                         98
# 20                        83                0.83                         84
# 21                        85                0.85                         98
# 22                        83                0.83                         79
# 23                        80                0.80                         96
# 24                        89                0.89                         97
# 25                        94                0.94                         93
# 26                        96                0.96                        100
# 27                        84                0.84                         92
# 28                        88                0.88                         96
# 29                        66                0.66                         89
#
#     hédonicité_relative  eveil_relatif_brute  eveil_relatif  \
# 0                  0.85                   74           0.74
# 1                  0.99                   96           0.96
# 2                  0.80                  100           1.00
# 3                  0.81                   51           0.51
# 4                  0.86                   83           0.83
# 5                  0.87                   90           0.90
# 6                  0.93                   84           0.84
# 7                  0.87                   64           0.64
# 8                  0.94                   85           0.85
# 9                  0.97                   92           0.92
# 10                 0.86                   63           0.63
# 11                 0.95                   95           0.95
# 12                 0.91                   68           0.68
# 13                 0.94                   67           0.67
# 14                 0.74                   84           0.84
# 15                 0.81                   73           0.73
# 16                 0.94                   78           0.78
# 17                 0.93                   65           0.65
# 18                 0.99                   93           0.93
# 19                 0.98                   73           0.73
# 20                 0.84                   58           0.58
# 21                 0.98                   79           0.79
# 22                 0.79                   76           0.76
# 23                 0.96                   72           0.72
# 24                 0.97                   61           0.61
# 25                 0.93                   99           0.99
# 26                 1.00                   98           0.98
# 27                 0.92                   85           0.85
# 28                 0.96                   90           0.90
# 29                 0.89                   82           0.82
#
#     familarité_relative_brute  familiarité_relative  \
# 0                          77                  0.77
# 1                          99                  0.99
# 2                         100                  1.00
# 3                          76                  0.76
# 4                          91                  0.91
# 5                          81                  0.81
# 6                          97                  0.97
# 7                          70                  0.70
# 8                          26                  0.26
# 9                          94                  0.94
# 10                         85                  0.85
# 11                         95                  0.95
# 12                         97                  0.97
# 13                         96                  0.96
# 14                         64                  0.64
# 15                         96                  0.96
# 16                        100                  1.00
# 17                         94                  0.94
# 18                         85                  0.85
# 19                         62                  0.62
# 20                         69                  0.69
# 21                         94                  0.94
# 22                         65                  0.65
# 23                         77                  0.77
# 24                         76                  0.76
# 25                         99                  0.99
# 26                         96                  0.96
# 27                         97                  0.97
# 28                         95                  0.95
# 29                         99                  0.99
#
#     valence_émotionnelle_relative_brute  valence_émotionnelle_relative  \
# 0                                    86                           0.86
# 1                                    99                           0.99
# 2                                    83                           0.83
# 3                                    84                           0.84
# 4                                    92                           0.92
# 5                                    91                           0.91
# 6                                   100                           1.00
# 7                                    90                           0.90
# 8                                    88                           0.88
# 9                                    96                           0.96
# 10                                   75                           0.75
# 11                                   90                           0.90
# 12                                   91                           0.91
# 13                                   95                           0.95
# 14                                   91                           0.91
# 15                                   81                           0.81
# 16                                  100                           1.00
# 17                                   95                           0.95
# 18                                   92                           0.92
# 19                                   97                           0.97
# 20                                   67                           0.67
# 21                                   99                           0.99
# 22                                   82                           0.82
# 23                                   85                           0.85
# 24                                   83                           0.83
# 25                                   98                           0.98
# 26                                   96                           0.96
# 27                                   80                           0.80
# 28                                   97                           0.97
# 29                                   82                           0.82
#
#    Stimulus
# 0      Odor
# 1      Odor
# 2      Odor
# 3      Odor
# 4      Odor
# 5      Odor
# 6      Odor
# 7      Odor
# 8      Odor
# 9      Odor
# 10     Odor
# 11     Odor
# 12     Odor
# 13     Odor
# 14     Odor
# 15     Odor
# 16     Odor
# 17     Odor
# 18     Odor
# 19     Odor
# 20     Odor
# 21     Odor
# 22     Odor
# 23     Odor
# 24     Odor
# 25     Odor
# 26     Odor
# 27     Odor
# 28     Odor
# 29     Odor

# %%
fig, ax = plt.subplots()
gh.auto_stats(df = pd.concat([odeurs_choisies, musiques_choisies]),
              predictor = 'Stimulus', 
              outcome = 'hédonicité_relative',
              design = 'within',
             subject = 'participant',
             ax=ax,
             outcome_clean_label = 'Hedonicity (relative step)',
             outcome_unit = '/1',
             xtick_info = False,
             palette = {'Odor':'g','Music':'darkorange'})
ax.set_ylabel(ax.get_ylabel(), fontsize = 14)
ax.set_xticklabels(ax.get_xticklabels(), fontsize = 14)
ax.set_xlabel(ax.get_xlabel(), fontsize = 15)
fig.savefig(base_folder / 'Figures' / 'stimulus_scoring' / 'relative_hedonicity_stim_choisis.png', dpi = 300, bbox_inches = 'tight')
# Out:
# /home/valentin/.virtualenvs/py3.10_local/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
