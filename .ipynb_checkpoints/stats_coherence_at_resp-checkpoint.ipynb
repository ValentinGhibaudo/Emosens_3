# %%
import pandas as pd
import numpy as np
import seaborn as sns
import ghibtools as gh
import xarray as xr
import matplotlib.pyplot as plt
from params import subject_keys, eeg_chans, run_keys
from compute_coherence import coherence_at_resp_job
from bibliotheque import get_pos, init_nan_da, df_baseline
import mne
import os
from configuration import base_folder

# %%
concat = []
for run_key in run_keys:
    concat.append(coherence_at_resp_job.get(run_key).to_dataframe())
coherence = pd.concat(concat)
# Out:
# coherence_at_resp is processing ('P01_baseline',)
# coherence is processing ('P01_baseline',)
# coherence_at_resp is processing ('P01_music',)
# coherence is processing ('P01_music',)
# coherence_at_resp is processing ('P01_odor',)
# coherence is processing ('P01_odor',)
# coherence_at_resp is processing ('P03_baseline',)
# coherence is processing ('P03_baseline',)
# coherence_at_resp is processing ('P03_music',)
# coherence is processing ('P03_music',)
# coherence_at_resp is processing ('P03_odor',)
# coherence is processing ('P03_odor',)
# coherence_at_resp is processing ('P04_baseline',)
# coherence is processing ('P04_baseline',)
# coherence_at_resp is processing ('P04_music',)
# coherence is processing ('P04_music',)
# coherence_at_resp is processing ('P04_odor',)
# coherence is processing ('P04_odor',)
# coherence_at_resp is processing ('P05_baseline',)
# coherence is processing ('P05_baseline',)
# coherence_at_resp is processing ('P05_music',)
# coherence is processing ('P05_music',)
# coherence_at_resp is processing ('P05_odor',)
# coherence is processing ('P05_odor',)
# coherence_at_resp is processing ('P06_baseline',)
# coherence is processing ('P06_baseline',)
# coherence_at_resp is processing ('P06_music',)
# coherence is processing ('P06_music',)
# coherence_at_resp is processing ('P06_odor',)
# coherence is processing ('P06_odor',)
# coherence_at_resp is processing ('P09_baseline',)
# coherence is processing ('P09_baseline',)
# coherence_at_resp is processing ('P09_music',)
# coherence is processing ('P09_music',)
# coherence_at_resp is processing ('P09_odor',)
# coherence is processing ('P09_odor',)

# %%
indexes = ['participant','session','chan']
metrics = ['fmax_resp','max_resp','max_coherence','log_max_coherence']

# %%
coherence = coherence.set_index(indexes).astype(float).reset_index()
coherence['log_max_coherence'] = np.log(coherence['max_coherence'])

# %%
coherence
# Out:
#     participant   session chan  fmax_resp     max_resp  max_coherence  \
# 0           P01  baseline  Fp1   0.356259   882.435901       0.027298
# 1           P01  baseline   Fz   0.356259   882.435901       0.093940
# 2           P01  baseline   F3   0.356259   882.435901       0.080578
# 3           P01  baseline   F7   0.356259   882.435901       0.026322
# 4           P01  baseline  FT9   0.356259   882.435901       0.027211
# ..          ...       ...  ...        ...          ...            ...
# 646         P09      odor  FC6   0.131253  3193.665645       0.028607
# 647         P09      odor  FC2   0.131253  3193.665645       0.208896
# 648         P09      odor   F4   0.131253  3193.665645       0.005699
# 649         P09      odor   F8   0.131253  3193.665645       0.024128
# 650         P09      odor  Fp2   0.131253  3193.665645       0.161442
#
#      log_max_coherence
# 0            -3.600945
# 1            -2.365099
# 2            -2.518531
# 3            -3.637365
# 4            -3.604137
# ..                 ...
# 646          -3.554098
# 647          -1.565917
# 648          -5.167485
# 649          -3.724362
# 650          -1.823611
#
# [651 rows x 7 columns]

# %%
coherence_baselined = df_baseline(coherence, indexes, metrics, mode = 'substract')

# %%
coherence_baselined
# Out:
#     participant session chan  fmax_resp     max_resp  max_coherence  \
# 0           P01    odor  Fp1        0.0  -457.441046      -0.019530
# 1           P01    odor   Fz        0.0  -457.441046      -0.025588
# 2           P01    odor   F3        0.0  -457.441046       0.007871
# 3           P01    odor   F7        0.0  -457.441046      -0.023718
# 4           P01    odor  FT9        0.0  -457.441046      -0.017519
# ..          ...     ...  ...        ...          ...            ...
# 429         P09   music  FC6        0.0 -1381.624873      -0.144146
# 430         P09   music  FC2        0.0 -1381.624873      -0.050975
# 431         P09   music   F4        0.0 -1381.624873       0.043703
# 432         P09   music   F8        0.0 -1381.624873      -0.167953
# 433         P09   music  Fp2        0.0 -1381.624873      -0.070715
#
#      log_max_coherence
# 0            -1.256856
# 1            -0.317985
# 2             0.093200
# 3            -2.313502
# 4            -1.032374
# ..                 ...
# 429          -0.850933
# 430          -1.892018
# 431           0.778278
# 432          -0.950838
# 433          -0.840314
#
# [434 rows x 7 columns]

# %%
sns.heatmap(coherence.corr(), cmap = 'seismic', vmin = -1 , vmax = 1 , annot = True)
# Out:
# /tmp/ipykernel_2953338/3824715237.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(coherence.corr(), cmap = 'seismic', vmin = -1 , vmax = 1 , annot = True)
# <AxesSubplot: >

# %%
coherence_baselined['log_max_coherence'].plot.hist(bins = 50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
pos = get_pos()

# %%
q_diff = 0.

df = coherence_baselined

N = df['participant'].unique().size

vmin = df.groupby(['session','chan']).mean(numeric_only = True)['log_max_coherence'].quantile(q_diff)
vmax = df.groupby(['session','chan']).mean(numeric_only = True)['log_max_coherence'].quantile(1 - q_diff)

vmin = vmin if abs(vmin) > abs(vmax) else -vmax
vmax = vmax if abs(vmax) > abs(vmin) else abs(vmin)

fig, axs = plt.subplots(ncols = df['session'].unique().size, figsize = (10,5))
fig.suptitle(f'EEG-Respi LogCoherence at respiration frequency, N = {N}', fontsize = 20, y = 1.1)

for c, session in enumerate(df['session'].unique()):
    ax = axs[c]
    topo_data = df[df['session'] == session].groupby('chan').mean(numeric_only = True)['max_coherence'].reindex(eeg_chans)
    im, cn = mne.viz.plot_topomap(data = topo_data.values , pos = pos, names = eeg_chans, axes = ax, show = False, vlim = (vmin,vmax))
    ax.set_title(f'{session}')
        
ax_x_start = 1
ax_x_width = 0.04
ax_y_start = 0.1
ax_y_height = 0.9
cbar_ax = fig.add_axes([ax_x_start, ax_y_start, ax_x_width, ax_y_height])
clb = fig.colorbar(im, cax=cbar_ax)
clb.ax.set_title('LogCoherence to baseline',fontsize=15)

file = base_folder / 'Figures' / 'coherence_at_resp' / 'log_coherence_substract_baseline.png'
if not os.path.isfile(file):
    print('SAVING')
    fig.savefig(file, bbox_inches = 'tight')
else:
    print('ALREADY SAVED')
    
fig.show()
# Out:
# ALREADY SAVED

# %%
q_diff = 0.

for subject in subject_keys:
    df = coherence_baselined[coherence_baselined['participant'] == subject]

    vmin = df.groupby(['session','chan']).mean(numeric_only = True)['max_coherence'].quantile(q_diff)
    vmax = df.groupby(['session','chan']).mean(numeric_only = True)['max_coherence'].quantile(1 - q_diff)
    
    vmin = vmin if abs(vmin) > abs(vmax) else -vmax
    vmax = vmax if abs(vmax) > abs(vmin) else abs(vmin)

    fig, axs = plt.subplots(ncols = df['session'].unique().size, figsize = (10,5))
    fig.suptitle(f'EEG-Respi LogCoherence at respiration frequency, sub = {subject}', fontsize = 20, y = 1.1)

    for c, session in enumerate(df['session'].unique()):
        ax = axs[c]
        topo_data = df[df['session'] == session].groupby('chan').mean(numeric_only = True)['max_coherence'].reindex(eeg_chans)
        im, cn = mne.viz.plot_topomap(data = topo_data.values , pos = pos, names = eeg_chans, axes = ax, show = False, vlim = (vmin,vmax))
        ax.set_title(f'{session}')

    ax_x_start = 1
    ax_x_width = 0.04
    ax_y_start = 0.1
    ax_y_height = 0.9
    cbar_ax = fig.add_axes([ax_x_start, ax_y_start, ax_x_width, ax_y_height])
    clb = fig.colorbar(im, cax=cbar_ax)
    clb.ax.set_title('Log coherence to baseline',fontsize=15)

    file = base_folder / 'Figures' / 'coherence_at_resp' / 'by_subject' / f'{subject}.png'
    
    if not os.path.isfile(file):
        print('SAVING')
        fig.savefig(file, bbox_inches = 'tight')
    else:
        print('ALREADY SAVED')

    fig.show()
# Out:
# ALREADY SAVED
# ALREADY SAVED
# ALREADY SAVED
# ALREADY SAVED
# ALREADY SAVED
# ALREADY SAVED
# ALREADY SAVED
