# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from compute_psycho import relaxation_job, emotions_job
import ghibtools as gh
from params import *
from bibliotheque import df_baseline
from configuration import *

# %% [markdown]
# # RELAXATION

# %%
metrics = ['Arousal','Relaxation','Relaxation_intensity','Perceived_duration']

clean_label = {'Arousal':'Arousal',
              'Relaxation':'Relaxation',
              'Relaxation_intensity':'Relaxation Intensity',
              'Perceived_duration':'Perceived Duration'}

indexes = ['participant','session']

# %%
concat = []
for participant in subject_keys:
    concat.append(relaxation_job.get(participant).to_dataframe())
df = pd.concat(concat).reset_index(drop = True)
df = df.drop(columns = ['stim_name'])
df[metrics] = df[metrics].astype(float)

# %%
df_ratio = df_baseline(df, indexes, metrics)

# %%
df
# Out:
#    participant   session  Arousal  Relaxation  Relaxation_intensity
# 0          P01  baseline     11.0        10.0                   4.0  \
# 1          P01     music     24.0        66.0                  61.0
# 2          P01      odor     13.0        67.0                  61.0
# 3          P02  baseline      7.0        93.0                  95.0
# 4          P02     music     35.0        89.0                  91.0
# ..         ...       ...      ...         ...                   ...
# 85         P30     music     86.0        56.0                  78.0
# 86         P30      odor     36.0        93.0                  87.0
# 87         P31  baseline     22.0        75.0                  67.0
# 88         P31     music     83.0        65.0                  67.0
# 89         P31      odor     60.0        68.0                  77.0
#
#     Perceived_duration
# 0                 96.0
# 1                 75.0
# 2                 87.0
# 3                 62.0
# 4                 59.0
# ..                 ...
# 85                55.0
# 86                59.0
# 87                12.0
# 88                22.0
# 89                12.0
#
# [90 rows x 6 columns]

# %%
df_ratio
# Out:
#    participant session     Arousal  Relaxation  Relaxation_intensity
# 0          P01    odor    1.181818    6.700000             15.250000  \
# 1          P02    odor    9.142857    0.698925              0.863158
# 2          P03    odor    1.909091    1.151515              1.107692
# 3          P04    odor    2.041667    1.265625              0.957746
# 4          P05    odor    8.500000    0.926316              0.896907
# 5          P06    odor    3.222222    1.261538              1.303030
# 6          P07    odor    5.272727    0.955224              0.840580
# 7          P08    odor    0.928571    0.866667              0.920000
# 8          P09    odor    1.741935    1.365385              1.283019
# 9          P10    odor   23.000000    1.186667              2.827586
# 10         P11    odor    1.222222    1.128571              1.459016
# 11         P12    odor    6.000000    1.012821              0.948052
# 12         P13    odor    1.714286    1.000000              0.901408
# 13         P14    odor    1.280000    0.840909              1.121951
# 14         P15    odor    1.152174    0.825000              0.936508
# 15         P16    odor    8.571429    1.047059              1.121951
# 16         P17    odor   18.000000    2.272727              1.750000
# 17         P18    odor    1.684211    1.038462              1.173333
# 18         P19    odor    1.760000    2.925926              3.250000
# 19         P20    odor    4.333333    1.218750              1.250000
# 20         P21    odor    6.333333    0.958904              0.842105
# 21         P23    odor    7.142857    0.986667              1.388889
# 22         P24    odor    1.428571    0.886364              1.046512
# 23         P25    odor    1.073171    0.982143              0.870968
# 24         P26    odor    1.380952    1.101449              1.517241
# 25         P27    odor    1.150000    0.869565              0.870968
# 26         P28    odor    1.033898    0.986301              1.233333
# 27         P29    odor    0.920000    1.237288              1.074627
# 28         P30    odor    9.000000    1.291667              1.581818
# 29         P31    odor    2.727273    0.906667              1.149254
# 30         P01   music    2.181818    6.600000             15.250000
# 31         P02   music    5.000000    0.956989              0.957895
# 32         P03   music    1.212121    1.060606              1.246154
# 33         P04   music    3.333333    1.031250              0.873239
# 34         P05   music    8.900000    0.915789              0.958763
# 35         P06   music    1.888889    0.815385              1.303030
# 36         P07   music    7.181818    1.000000              1.101449
# 37         P08   music    4.071429    0.173333              1.000000
# 38         P09   music    1.483871    1.423077              1.452830
# 39         P10   music   16.750000    1.160000              2.413793
# 40         P11   music    8.111111    0.971429              1.196721
# 41         P12   music    4.928571    1.179487              1.116883
# 42         P13   music    1.771429    1.354839              1.239437
# 43         P14   music    0.700000    1.090909              1.073171
# 44         P15   music    1.108696    0.800000              0.968254
# 45         P16   music   12.428571    1.035294              1.109756
# 46         P17   music  100.000000    1.931818              1.613636
# 47         P18   music    3.578947    0.256410              0.466667
# 48         P19   music    2.000000    2.629630              3.291667
# 49         P20   music   10.444444    0.687500              0.968750
# 50         P21   music    3.833333    0.945205              0.973684
# 51         P23   music   11.000000    0.253333              0.277778
# 52         P24   music    6.428571    0.840909              0.825581
# 53         P25   music    1.487805    1.392857              1.048387
# 54         P26   music    1.666667    1.000000              1.310345
# 55         P27   music    0.075000    1.032609              1.021505
# 56         P28   music    1.016949    1.041096              1.150000
# 57         P29   music    2.600000    1.016949              1.044776
# 58         P30   music   21.500000    0.777778              1.418182
# 59         P31   music    3.772727    0.866667              1.000000
#
#     Perceived_duration
# 0             0.906250
# 1             0.500000
# 2            14.666667
# 3             1.000000
# 4             0.767677
# 5             0.812500
# 6             1.050000
# 7             1.520000
# 8             0.690476
# 9             0.552632
# 10            1.164179
# 11            0.349206
# 12            0.862069
# 13            0.139535
# 14            0.924242
# 15            0.722222
# 16            0.216867
# 17            0.968254
# 18            1.400000
# 19            0.960000
# 20            0.704225
# 21            1.800000
# 22            1.107143
# 23            0.684211
# 24            0.638298
# 25            0.936508
# 26            0.362319
# 27            0.057471
# 28            1.053571
# 29            1.000000
# 30            0.781250
# 31            0.951613
# 32           19.000000
# 33            0.220000
# 34            0.565657
# 35            0.979167
# 36            0.225000
# 37            1.440000
# 38            0.952381
# 39            1.815789
# 40            0.686567
# 41            0.682540
# 42            0.862069
# 43            0.023256
# 44            1.060606
# 45            1.000000
# 46            0.433735
# 47            1.238095
# 48            1.860000
# 49            0.893333
# 50            0.760563
# 51            3.666667
# 52            0.500000
# 53            0.877193
# 54            0.765957
# 55            1.031746
# 56            0.637681
# 57            0.367816
# 58            0.982143
# 59            1.833333

# %%
nrows = 2
ncols = 4

fig , axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (20,10), constrained_layout = True)
fig.suptitle('Psychometrics', y = 1.05 , fontsize = 20)

for i, col in enumerate(metrics):
    ax = axs[0,i]
    gh.auto_stats(df = df, predictor = 'session', outcome = col, design = 'within', subject = 'participant', ax=ax, outcome_clean_label = clean_label[col], outcome_unit = '/100')
    
    ax = axs[1,i]
    gh.auto_stats(df = df_ratio, predictor = 'session', outcome = col, design = 'within', subject = 'participant', ax=ax, outcome_clean_label = clean_label[col])
 
fig.savefig(base_folder / 'Figures' / 'Psycho' / 'psycho_relaxation.png', bbox_inches = 'tight')
# Out:
# /home/valentin.ghibaudo/.virtualenvs/py3.10_nodegpu/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /home/valentin.ghibaudo/.virtualenvs/py3.10_nodegpu/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /home/valentin.ghibaudo/.virtualenvs/py3.10_nodegpu/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /home/valentin.ghibaudo/.virtualenvs/py3.10_nodegpu/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %%
df['log_Relaxation'] = np.log(df['Relaxation'])

# %%
sns.heatmap(df.corr('spearman',numeric_only = True), annot = True, cmap = 'seismic' , vmin = - 1, vmax = 1)
# Out:
# <AxesSubplot: >

# %%
ncols = len(session_keys)

fig, axs = plt.subplots(ncols = ncols, figsize = (18,5), constrained_layout = True)
fig.suptitle('Spearman correlation between psychometrics', fontsize = 20, y = 1.05)

for c, ses in enumerate(session_keys):
    ax = axs[c]
    sns.heatmap(df[df['session'] == ses].corr('spearman',numeric_only = True), annot = True, cmap = 'seismic' , vmin = - 1, vmax = 1, ax=ax)
    ax.set_title(ses)

fig.savefig(base_folder / 'Figures' / 'Psycho' / 'correlation_relaxation.png', bbox_inches = 'tight')

# %% [markdown]
# # EMOTIONS

# %%
metrics = ['Intensity','Hedonicity','Memories','Irritability','Emotional_Valence','Emotional_Intensity']

clean_label = {'Intensity':'Intensity',
               'Hedonicity':'Hedonicity',
               'Memories':'Memories',
               'Irritability':'Irritability',
               'Emotional_Valence':'Emotional Valence',
               'Emotional_Intensity':'Emotional Intensity'
              }

indexes = ['participant','session']

# %%
concat = []
for participant in subject_keys:
    concat.append(emotions_job.get(participant).to_dataframe())
df = pd.concat(concat).reset_index(drop = True)
df[metrics] = df[metrics].astype(float)

# %%
df
# Out:
#    participant session              stim_name  Intensity  Hedonicity
# 0          P01    odor  Fleur d'oranger épicé       60.0        81.0  \
# 1          P01   music              Classique       41.0        71.0
# 2          P02    odor                Vanille       85.0        83.0
# 3          P02   music              Classique       58.0        89.0
# 4          P03    odor                   Rose       80.0       100.0
# 5          P03   music              Classique       67.0        73.0
# 6          P04    odor                Vanille       43.0        82.0
# 7          P04   music                  Metal       78.0        91.0
# 8          P05    odor  Fleur d'oranger épicé       72.0        86.0
# 9          P05   music                   Raga       86.0        86.0
# 10         P06    odor      Floral printanier       40.0        78.0
# 11         P06   music              Classique       55.0        94.0
# 12         P07    odor      Floral printanier       59.0        74.0
# 13         P07   music                   Jazz       58.0        85.0
# 14         P08    odor                Vanille       29.0        81.0
# 15         P08   music                    Pop       56.0        81.0
# 16         P09    odor         Fleur de coton       31.0        61.0
# 17         P09   music             Rap freeze       63.0        99.0
# 18         P10    odor                Vanille       67.0        91.0
# 19         P10   music                   Jazz       50.0        75.0
# 20         P11    odor                Vanille       71.0        85.0
# 21         P11   music                Variety       72.0        94.0
# 22         P12    odor             Blue ocean       88.0        82.0
# 23         P12   music              Classique       69.0        94.0
# 24         P13    odor      Floral Printanier       68.0        80.0
# 25         P13   music                Rap Luv       66.0        84.0
# 26         P14    odor                Oxygène       53.0        82.0
# 27         P14   music                   Jazz       68.0       100.0
# 28         P15    odor         Fleur de coton       48.0        73.0
# 29         P15   music                   Raga       48.0        63.0
# 30         P16    odor      Floral Printanier       91.0        95.0
# 31         P16   music                Electro       92.0        99.0
# 32         P17    odor      Floral printanier       77.0        89.0
# 33         P17   music                  Metal       66.0        89.0
# 34         P18    odor         Fleur de coton       59.0        95.0
# 35         P18   music              Hard Rock       79.0        67.0
# 36         P19    odor                Vanille       35.0       100.0
# 37         P19   music             Rap Freeze       91.0       100.0
# 38         P20    odor                   Rose       64.0        90.0
# 39         P20   music                Electro       85.0        96.0
# 40         P21    odor         Fleur de coton       78.0        67.0
# 41         P21   music                Variety       67.0        60.0
# 42         P23    odor                Vanille       50.0        55.0
# 43         P23   music                    Pop       70.0        17.0
# 44         P24    odor                   Rose       72.0        78.0
# 45         P24   music                  Metal       69.0        82.0
# 46         P25    odor                Oxygène       70.0        76.0
# 47         P25   music              Classique       78.0        85.0
# 48         P26    odor                Vanille       77.0        86.0
# 49         P26   music              Hard Rock       67.0        81.0
# 50         P27    odor  Fleur d'oranger épicé       59.0        88.0
# 51         P27   music                   Jazz       51.0        81.0
# 52         P28    odor             Bois épicé       53.0        63.0
# 53         P28   music                Rap Luv       58.0        63.0
# 54         P29    odor      Floral Printanier       69.0        50.0
# 55         P29   music                Rap Luv       65.0        93.0
# 56         P30    odor          Pêche Lavande       59.0        92.0
# 57         P30   music                Electro       70.0        88.0
# 58         P31    odor          Pêche Lavande       63.0        81.0
# 59         P31   music                  Metal       74.0        85.0
#
#     Memories  Irritability  Emotional_Valence  Emotional_Intensity
# 0        7.0          19.0               61.0                 55.0
# 1       77.0          18.0               67.0                 77.0
# 2       96.0          57.0               94.0                 87.0
# 3       60.0          14.0               84.0                 43.0
# 4      100.0           2.0              100.0                 83.0
# 5       61.0           2.0               67.0                 51.0
# 6       49.0           0.0               84.0                 64.0
# 7       80.0           3.0               96.0                 80.0
# 8       76.0           3.0               85.0                 80.0
# 9       95.0           1.0               97.0                 92.0
# 10      31.0           9.0               84.0                 54.0
# 11      53.0           3.0               81.0                 61.0
# 12      77.0           5.0               91.0                 66.0
# 13      50.0           0.0              100.0                 57.0
# 14      58.0          10.0               86.0                 24.0
# 15      25.0           4.0               91.0                 50.0
# 16      63.0           2.0               52.0                 53.0
# 17      59.0           2.0               82.0                 66.0
# 18      66.0           0.0               87.0                 71.0
# 19      68.0           0.0               78.0                 65.0
# 20      67.0           1.0               90.0                 65.0
# 21      93.0           3.0               64.0                 63.0
# 22      67.0           9.0               83.0                 67.0
# 23      74.0           6.0               83.0                 73.0
# 24      63.0          20.0               69.0                 56.0
# 25      84.0          18.0               74.0                 69.0
# 26      13.0           0.0               69.0                 58.0
# 27      78.0           0.0               92.0                 90.0
# 28      60.0           1.0               71.0                 53.0
# 29      62.0           9.0               71.0                 49.0
# 30     100.0          13.0               91.0                 91.0
# 31      93.0           4.0               92.0                 88.0
# 32      67.0           2.0               91.0                 79.0
# 33      59.0           2.0               91.0                 76.0
# 34      99.0           7.0               90.0                 53.0
# 35      88.0          50.0               70.0                 49.0
# 36      80.0           7.0               93.0                 67.0
# 37      90.0           0.0               80.0                 88.0
# 38       9.0           2.0               89.0                 56.0
# 39      68.0           2.0               98.0                 88.0
# 40      56.0          10.0               63.0                 57.0
# 41      62.0          23.0               53.0                 54.0
# 42      49.0           0.0               61.0                 18.0
# 43      50.0          67.0               46.0                 44.0
# 44      61.0          10.0               74.0                 54.0
# 45      64.0           9.0               82.0                 75.0
# 46      38.0           9.0               78.0                 26.0
# 47      75.0           9.0               85.0                 70.0
# 48      58.0           0.0               87.0                 87.0
# 49      70.0           0.0               79.0                 65.0
# 50      65.0           4.0               38.0                 68.0
# 51      57.0           5.0               55.0                 74.0
# 52      68.0          25.0               73.0                 82.0
# 53      75.0          32.0               81.0                 68.0
# 54      99.0           7.0               50.0                 81.0
# 55      17.0           1.0               87.0                 77.0
# 56      85.0          10.0               80.0                 54.0
# 57      77.0          13.0               87.0                 72.0
# 58      65.0          11.0               61.0                 59.0
# 59      20.0          18.0               82.0                 78.0

# %%
nrows = 2
ncols = 3

array_metrics = np.array(metrics).reshape(nrows, ncols)

fig , axs = plt.subplots(nrows = nrows, ncols = ncols, figsize = (15,7), constrained_layout = True)
fig.suptitle('Emotional metrics according to the stimulus', y = 1.05 , fontsize = 20)

for r in range(nrows):
    for c in range(ncols):

        ax = axs[r,c]
        metric = array_metrics[r,c]
        gh.auto_stats(df = df, predictor = 'session', outcome = metric, design = 'within', subject = 'participant', ax=ax, outcome_clean_label = clean_label[metric], outcome_unit = '/100')

fig.savefig(base_folder / 'Figures' / 'Psycho' / 'psycho_emotions.png', bbox_inches = 'tight')
# Out:
# /home/valentin.ghibaudo/.virtualenvs/py3.10_nodegpu/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /home/valentin.ghibaudo/.virtualenvs/py3.10_nodegpu/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /home/valentin.ghibaudo/.virtualenvs/py3.10_nodegpu/lib/python3.10/site-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %%
ncols = 2

fig, axs = plt.subplots(ncols = ncols, figsize = (18,8), constrained_layout = True)
fig.suptitle('Spearman correlation between emotion metrics', fontsize = 20, y = 1.05)

for c, ses in enumerate(['odor','music']):
    ax = axs[c]
    sns.heatmap(df[df['session'] == ses].corr('spearman',numeric_only = True), annot = True, cmap = 'seismic' , vmin = - 1, vmax = 1, ax=ax)
    ax.set_title(ses)

fig.savefig(base_folder / 'Figures' / 'Psycho' / 'correlation_emotions.png', bbox_inches = 'tight')
