# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import mne
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import ghibtools as gh
import pandas as pd
import seaborn as sns
from params import *
from bibliotheque import get_pos, df_baseline
from compute_bandpower import bandpower_job
from configuration import base_folder
import os

# %%
pos = get_pos()

# %%
metrics = ['power_mean','power_median','power_integral']
indexes = ['band','session','chan','participant']

# %%
concat = []
for run_key in run_keys:
    concat.append(bandpower_job.get(run_key).to_dataframe())
bandpower = pd.concat(concat)
# Out:
# bandpower is processing ('P01_baseline',)
# psd_eeg is processing ('P01_baseline',)
# bandpower is processing ('P01_music',)
# psd_eeg is processing ('P01_music',)
# bandpower is processing ('P01_odor',)
# psd_eeg is processing ('P01_odor',)
# bandpower is processing ('P02_baseline',)
# psd_eeg is processing ('P02_baseline',)
# bandpower is processing ('P02_music',)
# psd_eeg is processing ('P02_music',)
# bandpower is processing ('P02_odor',)
# psd_eeg is processing ('P02_odor',)
# bandpower is processing ('P03_baseline',)
# psd_eeg is processing ('P03_baseline',)
# bandpower is processing ('P03_music',)
# psd_eeg is processing ('P03_music',)
# bandpower is processing ('P03_odor',)
# psd_eeg is processing ('P03_odor',)
# bandpower is processing ('P04_baseline',)
# psd_eeg is processing ('P04_baseline',)
# bandpower is processing ('P04_music',)
# psd_eeg is processing ('P04_music',)
# bandpower is processing ('P04_odor',)
# psd_eeg is processing ('P04_odor',)
# bandpower is processing ('P05_baseline',)
# psd_eeg is processing ('P05_baseline',)
# bandpower is processing ('P05_music',)
# psd_eeg is processing ('P05_music',)
# bandpower is processing ('P05_odor',)
# psd_eeg is processing ('P05_odor',)
# bandpower is processing ('P06_baseline',)
# psd_eeg is processing ('P06_baseline',)
# bandpower is processing ('P06_music',)
# psd_eeg is processing ('P06_music',)
# bandpower is processing ('P06_odor',)
# psd_eeg is processing ('P06_odor',)
# bandpower is processing ('P07_baseline',)
# psd_eeg is processing ('P07_baseline',)
# bandpower is processing ('P07_music',)
# psd_eeg is processing ('P07_music',)
# bandpower is processing ('P07_odor',)
# psd_eeg is processing ('P07_odor',)
# bandpower is processing ('P08_baseline',)
# psd_eeg is processing ('P08_baseline',)
# bandpower is processing ('P08_music',)
# psd_eeg is processing ('P08_music',)
# bandpower is processing ('P08_odor',)
# psd_eeg is processing ('P08_odor',)
# bandpower is processing ('P09_baseline',)
# psd_eeg is processing ('P09_baseline',)
# bandpower is processing ('P09_music',)
# psd_eeg is processing ('P09_music',)
# bandpower is processing ('P09_odor',)
# psd_eeg is processing ('P09_odor',)
# bandpower is processing ('P10_baseline',)
# psd_eeg is processing ('P10_baseline',)
# bandpower is processing ('P10_music',)
# psd_eeg is processing ('P10_music',)
# bandpower is processing ('P10_odor',)
# psd_eeg is processing ('P10_odor',)
# bandpower is processing ('P12_baseline',)
# psd_eeg is processing ('P12_baseline',)
# bandpower is processing ('P12_music',)
# psd_eeg is processing ('P12_music',)
# bandpower is processing ('P12_odor',)
# psd_eeg is processing ('P12_odor',)

# %%
bandpower_baselined = df_baseline(bandpower, indexes, metrics)

# %%
sns.heatmap(bandpower.corr(), annot =True, vmin = -1, vmax = 1, cmap = 'seismic')
# Out:
# /tmp/ipykernel_3089975/2367888301.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(bandpower.corr(), annot =True, vmin = -1, vmax = 1, cmap = 'seismic')
# <AxesSubplot: >

# %%
sns.heatmap(bandpower_baselined.corr(), annot =True, vmin = -1, vmax = 1, cmap = 'seismic')
# Out:
# /tmp/ipykernel_3089975/572946421.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(bandpower_baselined.corr(), annot =True, vmin = -1, vmax = 1, cmap = 'seismic')
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.pointplot(data=bandpower, x = 'band', y = 'power_integral', hue = 'session',ax=ax)
# Out:
# <AxesSubplot: xlabel='band', ylabel='power_integral'>

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.pointplot(data=bandpower_baselined, x = 'band', y = 'power_integral', hue = 'session',ax=ax)
# Out:
# <AxesSubplot: xlabel='band', ylabel='power_integral'>

# %%
N = len(subject_keys)

for band in fbands.keys():
    bandpower_of_band = bandpower_baselined[bandpower_baselined['band'] == band]
    
    lc = fbands[band][0]
    hc = fbands[band][1]
    
    delta = 0.005
    mini = bandpower_of_band['power_integral'].quantile(delta)
    maxi = bandpower_of_band['power_integral'].quantile(1 - delta)
    
    vlim = (mini,maxi)

    fig, axs = plt.subplots(ncols = bandpower_of_band['session'].unique().size,figsize = (10,5), constrained_layout = True)
    fig.suptitle(f'Bandpower ratio to baseline : {band} band [{lc}-{hc}] Hz', fontsize = 20, y = 1.1)
    for c, session in enumerate(bandpower_of_band['session'].unique()):
        ax = axs[c]
        mask = bandpower_of_band[bandpower_of_band['session'] == session]
        data_ready = mask.groupby('chan').mean(numeric_only = True)['power_integral'].reindex(eeg_chans)
        data = data_ready.values
        im, _ = mne.viz.plot_topomap(data=data,pos = pos, names = eeg_chans, axes=ax, show = False, vlim=vlim, cmap = 'Reds')
        
        ax.set_title(f'{session} - N = {N}')
        
    ax_x_start = 1
    ax_x_width = 0.04
    ax_y_start = 0
    ax_y_height = 0.9
    cbar_ax = fig.add_axes([ax_x_start, ax_y_start, ax_x_width, ax_y_height])
    clb = fig.colorbar(im, cax=cbar_ax)
    clb.ax.set_title('Power ratio to baseline',fontsize=15)
    
    file = base_folder / 'Figures' / 'bandpower' / 'global' / f'{band}.png'
    

    fig.savefig(file, bbox_inches = 'tight')

# %%
N = len(subject_keys)

for subject in subject_keys:
    bandpower_subject = bandpower_baselined[bandpower_baselined['participant'] == subject]
    for band in fbands.keys():
        bandpower_of_band = bandpower_subject[bandpower_subject['band'] == band]

        lc = fbands[band][0]
        hc = fbands[band][1]

        delta = 0.005
        mini = bandpower_of_band['power_integral'].quantile(delta)
        maxi = bandpower_of_band['power_integral'].quantile(1 - delta)
        vlim = (mini,maxi)

        fig, axs = plt.subplots(ncols = bandpower_of_band['session'].unique().size,figsize = (10,5), constrained_layout = True)
        fig.suptitle(f'{subject} - Bandpower ratio to baseline : {band} band [{lc}-{hc}] Hz', fontsize = 20, y = 1.1)
        for c, session in enumerate(bandpower_of_band['session'].unique()):
            ax = axs[c]
            mask = bandpower_of_band[bandpower_of_band['session'] == session]
            data_ready = mask.groupby('chan').mean(numeric_only = True)['power_integral'].reindex(eeg_chans)
            data = data_ready.values
            im, _ = mne.viz.plot_topomap(data=data,pos = pos, names = eeg_chans, axes=ax, show = False, vlim=vlim, cmap = 'Reds')

            ax.set_title(f'{session}')

        ax_x_start = 1
        ax_x_width = 0.04
        ax_y_start = 0
        ax_y_height = 0.9
        cbar_ax = fig.add_axes([ax_x_start, ax_y_start, ax_x_width, ax_y_height])
        clb = fig.colorbar(im, cax=cbar_ax)
        clb.ax.set_title('Power ratio to baseline',fontsize=15)
        
        save_folder = base_folder / 'Figures' / 'bandpower' / 'by_subject' / f'{band}'
        if not os.path.isdir(save_folder):
            os.mkdir(save_folder)
            
        file = save_folder / f'{subject}.png'
        fig.savefig(file, bbox_inches = 'tight')
        plt.close()
# Out:
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
# SAVING
