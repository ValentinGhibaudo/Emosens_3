# %%
import ghibtools as gh
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import pingouin
from compute_resp_features import respiration_features_job
from params import *
import physio
from configuration import base_folder
import os

# %%
concat = []

for run_key in run_keys:
    participant, session = run_key.split('_')
    features = respiration_features_job.get(run_key).to_dataframe()
    features.insert(0, 'session', session)
    features.insert(0, 'participant', participant)
    features = features.groupby(['participant','session']).median().reset_index()
    concat.append(features)
resp = pd.concat(concat)
# Out:
# respiration_features is processing ('P01_baseline',)
# respiration_features is processing ('P01_music',)
# respiration_features is processing ('P01_odor',)
# respiration_features is processing ('P02_baseline',)
# respiration_features is processing ('P02_music',)
# respiration_features is processing ('P02_odor',)
# respiration_features is processing ('P03_baseline',)
# respiration_features is processing ('P03_music',)
# respiration_features is processing ('P03_odor',)
# respiration_features is processing ('P04_baseline',)
# respiration_features is processing ('P04_music',)
# respiration_features is processing ('P04_odor',)
# respiration_features is processing ('P05_baseline',)
# respiration_features is processing ('P05_music',)
# respiration_features is processing ('P05_odor',)
# respiration_features is processing ('P06_baseline',)
# respiration_features is processing ('P06_music',)
# respiration_features is processing ('P06_odor',)
# respiration_features is processing ('P07_baseline',)
# respiration_features is processing ('P07_music',)
# respiration_features is processing ('P07_odor',)
# respiration_features is processing ('P08_baseline',)
# respiration_features is processing ('P08_music',)
# respiration_features is processing ('P08_odor',)
# respiration_features is processing ('P09_baseline',)
# respiration_features is processing ('P09_music',)
# respiration_features is processing ('P09_odor',)
# respiration_features is processing ('P10_baseline',)
# respiration_features is processing ('P10_music',)
# respiration_features is processing ('P10_odor',)
# respiration_features is processing ('P11_baseline',)
# respiration_features is processing ('P11_music',)
# respiration_features is processing ('P11_odor',)
# respiration_features is processing ('P12_baseline',)
# respiration_features is processing ('P12_music',)
# respiration_features is processing ('P12_odor',)
# respiration_features is processing ('P13_baseline',)
# respiration_features is processing ('P13_music',)
# respiration_features is processing ('P13_odor',)
# respiration_features is processing ('P14_baseline',)
# respiration_features is processing ('P14_music',)
# respiration_features is processing ('P14_odor',)
# respiration_features is processing ('P15_baseline',)
# respiration_features is processing ('P15_music',)
# respiration_features is processing ('P15_odor',)
# respiration_features is processing ('P16_baseline',)
# respiration_features is processing ('P16_music',)
# respiration_features is processing ('P16_odor',)
# respiration_features is processing ('P17_baseline',)
# respiration_features is processing ('P17_music',)
# respiration_features is processing ('P17_odor',)
# respiration_features is processing ('P18_baseline',)
# respiration_features is processing ('P18_music',)
# respiration_features is processing ('P18_odor',)
# respiration_features is processing ('P19_baseline',)
# respiration_features is processing ('P19_music',)
# respiration_features is processing ('P19_odor',)
# respiration_features is processing ('P20_baseline',)
# respiration_features is processing ('P20_music',)
# respiration_features is processing ('P20_odor',)
# respiration_features is processing ('P21_baseline',)
# respiration_features is processing ('P21_music',)
# respiration_features is processing ('P21_odor',)
# respiration_features is processing ('P22_baseline',)
# respiration_features is processing ('P22_music',)
# respiration_features is processing ('P22_odor',)
# respiration_features is processing ('P23_baseline',)
# respiration_features is processing ('P23_music',)
# respiration_features is processing ('P23_odor',)
# respiration_features is processing ('P24_baseline',)
# respiration_features is processing ('P24_music',)
# respiration_features is processing ('P24_odor',)
# respiration_features is processing ('P25_baseline',)
# respiration_features is processing ('P25_music',)
# respiration_features is processing ('P25_odor',)
# respiration_features is processing ('P26_baseline',)
# respiration_features is processing ('P26_music',)
# respiration_features is processing ('P26_odor',)
# respiration_features is processing ('P27_baseline',)
# respiration_features is processing ('P27_music',)
# respiration_features is processing ('P27_odor',)
# respiration_features is processing ('P28_baseline',)
# respiration_features is processing ('P28_music',)
# respiration_features is processing ('P28_odor',)
# respiration_features is processing ('P29_baseline',)
# respiration_features is processing ('P29_music',)
# respiration_features is processing ('P29_odor',)
# respiration_features is processing ('P30_baseline',)
# respiration_features is processing ('P30_music',)
# respiration_features is processing ('P30_odor',)
# respiration_features is processing ('P31_baseline',)
# respiration_features is processing ('P31_music',)
# respiration_features is processing ('P31_odor',)

# %%
def ratio_baseline(df, indexes, metrics):
    odor = df[df['session'] == 'odor'].set_index(indexes)
    music = df[df['session'] == 'music'].set_index(indexes)
    baseline = df[df['session'] == 'baseline'].set_index(indexes)
    
    data_odor = odor.values / baseline.values
    data_music = music.values / baseline.values
    
    df_odor = pd.DataFrame(data = data_odor, columns = metrics, index = odor.index)
    df_music = pd.DataFrame(data = data_music, columns = metrics, index = music.index)
    
    return pd.concat([df_odor, df_music]).reset_index()

# %%
metrics = ['cycle_duration','inspi_duration','expi_duration','cycle_ratio','inspi_volume','expi_volume','total_volume', 'inspi_amplitude', 'expi_amplitude']

# %%
indexes = ['participant','session']

# %%
all_cols = indexes + metrics

# %%
resp_baselined = ratio_baseline(resp[all_cols], indexes, metrics)

# %%
fig, ax = plt.subplots()
sns.heatmap(resp[metrics].corr('spearman'), annot = True, vmin=-1, vmax= 1 , cmap = 'seismic', ax=ax)
ax.set_title('Correlation matrix between respiration features')
file = base_folder / 'Figures' / 'resp_features' / 'corr_matrix_resp_features.png'
fig.savefig(file, bbox_inches = 'tight')
plt.show()

# %%
fig, axs = plt.subplots(ncols = 3, figsize = (18,5), constrained_layout = True)

for c, ses in enumerate(session_keys):
    ax = axs[c]
    resp_ses = resp[resp['session'] == ses]
    sns.heatmap(resp_ses[metrics].corr('spearman'), annot = True, vmin=-1, vmax= 1 , cmap = 'seismic', ax=ax)
    ax.set_title(f'Correlation matrix between respiration features during {ses}')
    
file = base_folder / 'Figures' / 'resp_features' / 'corr_matrix_resp_features_by_session.png'
fig.savefig(file, bbox_inches = 'tight')
plt.show()

# %%
nrows = 3
ncols = 3
plot_metrics = np.array(metrics).reshape(nrows, ncols)

for suptitle, df in zip(['Raw respiration features','Respiration features ratio to baseline'],[resp, resp_baselined]):

    fig, axs = plt.subplots(nrows, ncols, figsize = (15,15), constrained_layout = True)
    fig.suptitle(suptitle, fontsize = 20, y = 1.05)

    for r in range(nrows):
        for c in range(ncols):
            ax = axs[r,c]

            gh.auto_stats(df = df, predictor = 'session', outcome = plot_metrics[r,c], design = 'within', subject = 'participant', ax=ax)
            
            if suptitle == 'Respiration features ratio to baseline':
                ax.set_ylabel(f'{plot_metrics[r,c]} ratio to baseline')
            else:
                ax.set_ylabel(plot_metrics[r,c])
                
    file = base_folder / 'Figures' / 'resp_features' / f'{suptitle}.png'
    fig.savefig(file, bbox_inches = 'tight')
    plt.show()
