# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import ghibtools as gh
from params import *

# %%
participant = 'P05'

# %%
da = xr.load_dataarray(f'/crnldata/cmo/Etudiants/Valentin_G/Emosens_1/Preprocessing/Data_Epoched/{participant}_epoched.nc')

# %%
da.loc['odor_-','Free',1,'Fp1',:].dropna('time')
# Out:
# <xarray.DataArray (time: 300000)>
# array([-10826.13553302, -10826.19758732, -10825.0009675 , ...,
#        -12016.50990295, -12019.04369315, -12024.2425512 ])
# Coordinates:
#   * time     (time) float64 0.0 0.001 0.002 0.003 ... 300.0 300.0 300.0 300.0
#     chan     <U3 'Fp1'
#     bloc     <U4 'Free'
#     odor     <U6 'odor_-'
#     trial    int32 1

# %%
da.loc[:,:,:,'GSR',:].plot.line(x='time', hue ='trial', col = 'bloc', row = 'odor')
